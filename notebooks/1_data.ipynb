# %% [markdown]
# ## 🚀 Data preparation

# %% [markdown]
# ### 😵‍💫 Activate your environment

# %%
# Activate your environment
# Run it on your terminal please
! conda activate sentiment-analysis-on-movie-reviews

# %% [markdown]
# ### 🥇 Install Kaggle cli

# %%
# install kaggle cli
# on your terminal please
! conda install kaggle

# %% [markdown]
# ### 📈 Download data from Kaggle

# %%
! rm -rf ../data
# Download the dataset from kaggle
# Remember to join the competition first
# Also remember to generate API credentials
! mkdir ../data
! kaggle competitions download --force sentiment-analysis-on-movie-reviews --path ../data
! unzip ../data/sentiment-analysis-on-movie-reviews.zip -d ../data

! mkdir ../data/test
! mkdir ../data/train
! unzip ../data/test.tsv.zip -d ../data/test
! unzip ../data/train.tsv.zip -d ../data/train
