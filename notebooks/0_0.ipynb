# %% [markdown]
# # For image

# %% [markdown]
# ## 😀 Main for this notebook

# %% [markdown]
# ### 🎒 Packages

# %%
import pathlib
import pandas as pd

# %% [markdown]
# ### 🚙 Utilities

# %%
def function():
    return "OK"

# %% [markdown]
# ### 📊 Data

# %%
df = pd.DataFrame()
